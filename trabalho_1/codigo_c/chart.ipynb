# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import pathlib

# %%
csv_file_outside_j = os.path.abspath(os.getcwd())+'/outside_j_time.csv'
csv_file_outside_i = os.path.abspath(os.getcwd())+'/outside_i_time.csv'
csv_outside_i = pd.read_csv(csv_file_outside_i, usecols=['n','time'])
csv_outside_j = pd.read_csv(csv_file_outside_j, usecols=['n','time'])

# %%
i_y = list(csv_outside_i.time)[1:]
i_x = list(csv_outside_i.n)[1:]
j_y = list(csv_outside_j.time)[1:]
j_x = list(csv_outside_j.n)[1:]
plt.plot("n","time",data=csv_outside_i,label="outside_i")
plt.plot("n","time",data=csv_outside_j,label="outside_j")
plt.legend()
