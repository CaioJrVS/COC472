# %%
# Trecho do código para tratar os dados extraidos do fortran
#file = open("fortran_process_times_outside_j.csv")
#csv_content = file.read().replace(" ","")
#csv_content = csv_content.replace("\\n","\n")
#comma_counter = 0
#for i in range(len(csv_content)):
#    if(i<len(csv_content) and csv_content[i] == ","):
#        comma_counter += 1
#        if(comma_counter == 2 and (i+1) < len(csv_content)):
#            csv_content = csv_content[:i] + csv_content[i+1:]
#            comma_counter=0
#write_file = open("fortran_j_csv.csv","a")
#write_file.write(csv_content)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
outside_i= pd.read_csv("fortran_i_csv.csv")
outside_j= pd.read_csv("fortran_j_csv.csv")

plt.plot("n","time",data=outside_i,label="outside_i")
plt.plot("n","time",data=outside_j,label="outside_j")
plt.legend()
